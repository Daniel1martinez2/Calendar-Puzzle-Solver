# %% [markdown]
# # Daily Calendar Puzzle — Demo
#
# This notebook demonstrates the ILP-based solver for the Daily Calendar Puzzle.
# Each day, 10 polyomino pieces must tile the board leaving exactly three cells
# exposed: the current **month**, **day**, and **weekday** (Spanish labels).

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))

from calendar_puzzle import Board, Solver, Renderer

board = Board()
solver = Solver(board)
renderer = Renderer(board)

# %% [markdown]
# ## The Board
#
# An 8×7 grid with 50 playable cells — 12 months, 31 days, and 7 weekdays.

# %%
renderer.show_board({})
# Out:
# <table style="border-collapse:collapse;font:700 14px monospace;"><tr><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#f1f5f9;color:#94a3b8;border-top: 3px solid #334155; border-right: 3px solid #334155; border-bottom: 3px solid #334155; border-left: 3px solid #334155">ENE</td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#f1f5f9;color:#94a3b8;border-top: 3px solid #334155; border-right: 3px solid #334155; border-bottom: 3px solid #334155; border-left: 3px solid #334155">FEB</td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#f1f5f9;color:#94a3b8;border-top: 3px solid #334155; border-right: 3px solid #334155; border-bottom: 3px solid #334155; border-left: 3px solid #334155">MAR</td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#f1f5f9;color:#94a3b8;border-top: 3px solid #334155; border-right: 3px solid #334155; border-bottom: 3px solid #334155; border-left: 3px solid #334155">ABR</td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#f1f5f9;color:#94a3b8;border-top: 3px solid #334155; border-right: 3px solid #334155; border-bottom: 3px solid #334155; border-left: 3px solid #334155">MAY</td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#f1f5f9;color:#94a3b8;border-top: 3px solid #334155; border-right: 3px solid #334155; border-bottom: 3px solid #334155; border-left: 3px solid #334155">JUN</td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#1e1e1e;border:none;"></td></tr><tr><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#f1f5f9;color:#94a3b8;border-top: 3px solid #334155; border-right: 3px solid #334155; border-bottom: 3px solid #334155; border-left: 3px solid #334155">JUL</td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#f1f5f9;color:#94a3b8;border-top: 3px solid #334155; border-right: 3px solid #334155; border-bottom: 3px solid #334155; border-left: 3px solid #334155">AGO</td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#f1f5f9;color:#94a3b8;border-top: 3px solid #334155; border-right: 3px solid #334155; border-bottom: 3px solid #334155; border-left: 3px solid #334155">SEP</td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#f1f5f9;color:#94a3b8;border-top: 3px solid #334155; border-right: 3px solid #334155; border-bottom: 3px solid #334155; border-left: 3px solid #334155">OCT</td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#f1f5f9;color:#94a3b8;border-top: 3px solid #334155; border-right: 3px solid #334155; border-bottom: 3px solid #334155; border-left: 3px solid #334155">NOV</td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#f1f5f9;color:#94a3b8;border-top: 3px solid #334155; border-right: 3px solid #334155; border-bottom: 3px solid #334155; border-left: 3px solid #334155">DIC</td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#1e1e1e;border:none;"></td></tr><tr><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#f1f5f9;color:#94a3b8;border-top: 3px solid #334155; border-right: 3px solid #334155; border-bottom: 3px solid #334155; border-left: 3px solid #334155">1</td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#f1f5f9;color:#94a3b8;border-top: 3px solid #334155; border-right: 3px solid #334155; border-bottom: 3px solid #334155; border-left: 3px solid #334155">2</td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#f1f5f9;color:#94a3b8;border-top: 3px solid #334155; border-right: 3px solid #334155; border-bottom: 3px solid #334155; border-left: 3px solid #334155">3</td><td style="width:54p ...

# %% [markdown]
# ## The Pieces
#
# 10 polyomino pieces (4–5 cells each, 47 cells total) with all unique orientations.

# %%
renderer.show_pieces()
# Out:
# <div style="margin-bottom:12px;"><b style="font:700 13px monospace;">Piece A — 5 cells, 8 orientations</b><div style="display:flex;flex-wrap:wrap;align-items:flex-start;gap:8px;"><table style="border-collapse:collapse;display:inline-block;margin:4px;font:700 12px monospace;"><tr><td style="width:32px;height:32px;text-align:center;background:#ef4444;color:#fff;border-top:2px solid #334155;border-right:2px solid #ef4444;border-bottom:2px solid #ef4444;border-left:2px solid #334155;">A</td><td style="width:32px;height:32px;text-align:center;background:#ef4444;color:#fff;border-top:2px solid #334155;border-right:2px solid #334155;border-bottom:2px solid #ef4444;border-left:2px solid #ef4444;">A</td></tr><tr><td style="width:32px;height:32px;text-align:center;background:#ef4444;color:#fff;border-top:2px solid #ef4444;border-right:2px solid #ef4444;border-bottom:2px solid #334155;border-left:2px solid #334155;">A</td><td style="width:32px;height:32px;text-align:center;background:#ef4444;color:#fff;border-top:2px solid #ef4444;border-right:2px solid #334155;border-bottom:2px solid #ef4444;border-left:2px solid #ef4444;">A</td></tr><tr><td style="width:32px;height:32px;text-align:center;border:none;"></td><td style="width:32px;height:32px;text-align:center;background:#ef4444;color:#fff;border-top:2px solid #ef4444;border-right:2px solid #334155;border-bottom:2px solid #334155;border-left:2px solid #334155;">A</td></tr></table><table style="border-collapse:collapse;display:inline-block;margin:4px;font:700 12px monospace;"><tr><td style="width:32px;height:32px;text-align:center;background:#ef4444;color:#fff;border-top:2px solid #334155;border-right:2px solid #ef4444;border-bottom:2px solid #ef4444;border-left:2px solid #334155;">A</td><td style="width:32px;height:32px;text-align:center;background:#ef4444;color:#fff;border-top:2px solid #334155;border-right:2px solid #334155;border-bottom:2px solid #ef4444;border-left:2px solid #ef4444;">A</td></tr><tr><td style="width:32px;height:32px;text-align:center;background:#ef4444;color:#fff;border-top:2px solid #ef4444;border-right:2px solid #ef4444;border-bottom:2px solid #ef4444;border-left:2px solid #334155;">A</td><td style="width:32px;height:32px;text-align:center;background:#ef4444;color:#fff;border-top:2px solid #ef4444;border-right:2px solid #334155;border-bottom:2px solid #334155;border-left:2px solid #ef4444;">A</td></tr><tr><td style="width:32px;height:32px;text-align:center;background:#ef4444;color:#fff;border-top:2px solid #ef4444;border-right:2px solid #334155;border-bottom:2px solid #334155;border-left:2px solid #334155;">A</td><td style="width:32px;height:32px;text-align:center;border:none;"></td></tr></table><table style="border-collapse:collapse;display:inline-block;margin:4px;font:700 12px monospace;"><tr><td style="width:32px;height:32px;text-align:center;border:none;"></td><td style="width:32px;height:32px;text-align:center;background:#ef4444;color:#fff;border-top:2px solid #334155;border-right:2px solid #ef4444;border-bottom:2px solid #ef4444;border-left:2px solid #334155;">A</td><td style="width:32px;height:32px;text-align:center;background:#ef4444;color:#fff;border-top:2px solid #334155;border-right:2px solid #334155;border-bottom:2px solid #ef4444;border-left:2px solid #ef4444;">A</td></tr><tr><td style="width:32px;height:32px;text-align:center;background:#ef4444;color:#fff;border-top:2px solid #334155;border-right:2px solid #ef4444;border-bottom:2px solid #334155;border-left:2px solid #334155;">A</td><td style="width:32px;height:32px;text-align:center;background:#ef4444;color:#fff;border-top:2px solid #ef4444;border-right:2px solid #ef4444;border-bottom:2px solid #334155;border-left:2px solid #ef4444;">A</td><td style="width:32px;height:32px;text-align:center;background:#ef4444;color:#fff;border-top:2px solid #ef4444;border-right:2px solid #334155;border-bottom:2px solid #334155;border-left:2px solid #ef4444;">A</td></tr></table><table style="border-collapse:collapse;di ...

# %% [markdown]
# ## Solve: FEB 24 MAR (martes)
#
# Find a tiling that leaves February, 24, and Tuesday exposed.

# %%
result = solver.solve("FEB", 24, "MAR")
targets = board.target_cells("FEB", 24, "MAR")
renderer.show_board(result, targets, show_labels=False)
# Out:
# <table style="border-collapse:collapse;font:700 14px monospace;"><tr><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#facc15;color:#000;border-top: 3px solid #334155; border-right: 3px solid #334155; border-bottom: 1px solid rgba(0,0,0,0.06); border-left: 3px solid #334155"></td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#fef9c3;color:#92400e;border-top: 3px solid #334155; border-right: 3px solid #334155; border-bottom: 3px solid #334155; border-left: 3px solid #334155">FEB</td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#06b6d4;color:#000;border-top: 3px solid #334155; border-right: 1px solid rgba(0,0,0,0.06); border-bottom: 3px solid #334155; border-left: 3px solid #334155"></td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#06b6d4;color:#000;border-top: 3px solid #334155; border-right: 3px solid #334155; border-bottom: 1px solid rgba(0,0,0,0.06); border-left: 1px solid rgba(0,0,0,0.06)"></td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#3b82f6;color:#fff;border-top: 3px solid #334155; border-right: 1px solid rgba(0,0,0,0.06); border-bottom: 3px solid #334155; border-left: 3px solid #334155"></td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#3b82f6;color:#fff;border-top: 3px solid #334155; border-right: 3px solid #334155; border-bottom: 1px solid rgba(0,0,0,0.06); border-left: 1px solid rgba(0,0,0,0.06)"></td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#1e1e1e;border:none;"></td></tr><tr><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#facc15;color:#000;border-top: 1px solid rgba(0,0,0,0.06); border-right: 1px solid rgba(0,0,0,0.06); border-bottom: 3px solid #334155; border-left: 3px solid #334155"></td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#facc15;color:#000;border-top: 3px solid #334155; border-right: 1px solid rgba(0,0,0,0.06); border-bottom: 3px solid #334155; border-left: 1px solid rgba(0,0,0,0.06)"></td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#facc15;color:#000;border-top: 3px solid #334155; border-right: 3px solid #334155; border-bottom: 3px solid #334155; border-left: 1px solid rgba(0,0,0,0.06)"></td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#06b6d4;color:#000;border-top: 1px solid rgba(0,0,0,0.06); border-right: 1px solid rgba(0,0,0,0.06); border-bottom: 3px solid #334155; border-left: 3px solid #334155"></td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#06b6d4;color:#000;border-top: 3px solid #334155; border-right: 3px solid #334155; border-bottom: 3px solid #334155; border-left: 1px solid rgba(0,0,0,0.06)"></td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#3b82f6;color:#fff;border-top: 1px solid rgba(0,0,0,0.06); border-right: 3px solid #334155; border-bottom: 1px solid rgba(0,0,0,0.06); border-left: 3px solid #334155"></td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#1e1e1e;border:none;"></td></tr><tr><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#64748b;color:#fff;border-top: 3px solid #334155; border-right: 1px solid rgba(0,0,0,0.06); border-bottom: 3px solid #334155; border-left: 3px solid #334155"></td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#64748b;color:#fff;border-top: 3px solid #334155; border-right: 1px solid rgba(0,0,0,0.06); border-bottom: 3px solid #334155; border-left: 1px solid rgba(0,0,0,0.06)"></td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#64748b;color:#fff;border-top: 3px solid #334155; border-right: 3px soli ...

# %% [markdown]
# ## Solve: AGO 15 VIE (viernes)

# %%
result2 = solver.solve("AGO", 15, "VIE")
targets2 = board.target_cells("AGO", 15, "VIE")
renderer.show_board(result2, targets2, show_labels=False)
# Out:
# <table style="border-collapse:collapse;font:700 14px monospace;"><tr><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#f97316;color:#000;border-top: 3px solid #334155; border-right: 1px solid rgba(0,0,0,0.06); border-bottom: 1px solid rgba(0,0,0,0.06); border-left: 3px solid #334155"></td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#f97316;color:#000;border-top: 3px solid #334155; border-right: 1px solid rgba(0,0,0,0.06); border-bottom: 3px solid #334155; border-left: 1px solid rgba(0,0,0,0.06)"></td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#f97316;color:#000;border-top: 3px solid #334155; border-right: 3px solid #334155; border-bottom: 1px solid rgba(0,0,0,0.06); border-left: 1px solid rgba(0,0,0,0.06)"></td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#64748b;color:#fff;border-top: 3px solid #334155; border-right: 3px solid #334155; border-bottom: 1px solid rgba(0,0,0,0.06); border-left: 3px solid #334155"></td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#a855f7;color:#fff;border-top: 3px solid #334155; border-right: 3px solid #334155; border-bottom: 1px solid rgba(0,0,0,0.06); border-left: 3px solid #334155"></td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#22c55e;color:#fff;border-top: 3px solid #334155; border-right: 3px solid #334155; border-bottom: 1px solid rgba(0,0,0,0.06); border-left: 3px solid #334155"></td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#1e1e1e;border:none;"></td></tr><tr><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#f97316;color:#000;border-top: 1px solid rgba(0,0,0,0.06); border-right: 3px solid #334155; border-bottom: 3px solid #334155; border-left: 3px solid #334155"></td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#fef9c3;color:#92400e;border-top: 3px solid #334155; border-right: 3px solid #334155; border-bottom: 3px solid #334155; border-left: 3px solid #334155">AGO</td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#f97316;color:#000;border-top: 1px solid rgba(0,0,0,0.06); border-right: 3px solid #334155; border-bottom: 3px solid #334155; border-left: 3px solid #334155"></td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#64748b;color:#fff;border-top: 1px solid rgba(0,0,0,0.06); border-right: 3px solid #334155; border-bottom: 1px solid rgba(0,0,0,0.06); border-left: 3px solid #334155"></td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#a855f7;color:#fff;border-top: 1px solid rgba(0,0,0,0.06); border-right: 3px solid #334155; border-bottom: 1px solid rgba(0,0,0,0.06); border-left: 3px solid #334155"></td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#22c55e;color:#fff;border-top: 1px solid rgba(0,0,0,0.06); border-right: 3px solid #334155; border-bottom: 1px solid rgba(0,0,0,0.06); border-left: 3px solid #334155"></td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#1e1e1e;border:none;"></td></tr><tr><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#84cc16;color:#000;border-top: 3px solid #334155; border-right: 3px solid #334155; border-bottom: 1px solid rgba(0,0,0,0.06); border-left: 3px solid #334155"></td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#64748b;color:#fff;border-top: 3px solid #334155; border-right: 1px solid rgba(0,0,0,0.06); border-bottom: 3px solid #334155; border-left: 3px solid #334155"></td><td style="width:54px;height:54px;text-align:center;vertical-align:middle;background:#64748b;color:#fff;border-top: 3px solid #334155; border-right: 1px solid rgba(0, ...
